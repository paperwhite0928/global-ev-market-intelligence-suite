# %% [markdown]
# # 06 — Final Visualizations
#
# Export publication-ready charts to `outputs/charts/`.

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(ROOT))

from src.load_data import load_processed
from src.visualization import (
    plot_battery_index,
    plot_bev_market_share,
    plot_risk_heatmap,
    plot_toyota_mix_stacked,
)

mix = load_processed("toyota_mix")
bev = load_processed("bev_sales")
battery = load_processed("battery_index")
risk = load_processed("risk_summary")

charts = [
    plot_toyota_mix_stacked(mix, "Global"),
    plot_bev_market_share(bev, 2025),
    plot_battery_index(battery),
    plot_risk_heatmap(risk),
]
for c in charts:
    print(c)
