# %% [markdown]
# # 03 — EV Gold Rush
#
# Compare peer OEM BEV volumes, market share, and capital allocation.

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(ROOT))

from src.load_data import load_processed, load_raw
from src.visualization import plot_bev_market_share

bev = load_processed("bev_sales")
investments = load_raw("ev_investments")
bev[bev["company"] == "Toyota"]

# %%
plot_bev_market_share(bev, year=2025)

inv_total = investments.groupby(["year", "company"])["investment_usd_b"].sum().reset_index()
inv_total.pivot(index="year", columns="company", values="investment_usd_b").fillna(0)
