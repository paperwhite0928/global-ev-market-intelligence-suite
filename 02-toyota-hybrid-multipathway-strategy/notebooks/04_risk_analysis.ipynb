# %% [markdown]
# # 04 — Risk Analysis
#
# Battery material costs, charging gaps, and tariff/policy exposure by region.

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(ROOT))

from src.load_data import load_processed, load_raw
from src.visualization import plot_battery_index, plot_risk_heatmap

battery = load_processed("battery_index")
risk = load_processed("risk_summary")
tariffs = load_raw("tariff_events")
charging = load_raw("charging_infrastructure")

risk

# %%
plot_battery_index(battery)
plot_risk_heatmap(risk)
tariffs.sort_values("impact_score", ascending=False)
